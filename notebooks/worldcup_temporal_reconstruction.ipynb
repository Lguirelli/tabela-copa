# %% [markdown]
# # Reconstrução temporal da Copa 2026
# Este notebook executa o pipeline sem permitir dados futuros.

# %%
from worldcup_brain.config import load_config
from worldcup_brain.pipeline import prepare, replay
from worldcup_brain.validation import validate
config = load_config()

# %%
prepare(config)

# %% [markdown]
# ## Replay histórico parcial
# Altere o cutoff para observar o conhecimento acumulado em qualquer ponto da competição.

# %%
result = replay(config, as_of='2026-06-25T23:59:59-04:00')
result

# %%
validate(config, expect_complete=False)
